# %% [markdown]
# ## Loading Data 2010-2021

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# loading data
df = pd.read_csv("../CSV/2010-2021.csv")
# drop unused columns
df.drop('LOWEST SALE PRICE', axis=1, inplace=True)
df.drop('HIGHEST SALE PRICE', axis=1, inplace=True)
# create grouping of data using specified column then
# creates a copy of specified entry within the column group
borough = groupby_borough = df.groupby(['BOROUGH']).get_group(('STATEN ISLAND',)).copy()

# group further by home type
groupby_home = borough.groupby(['TYPE OF HOME'])
one = groupby_home.get_group(('01 ONE FAMILY HOMES',)).copy()
two = groupby_home.get_group(('02 TWO FAMILY HOMES',)).copy()
three = groupby_home.get_group(('03 THREE FAMILY HOMES',)).copy()

# %% [markdown]
# ## Setting up Model

# %%
# group home type into neighborhood
hood_names_one = one['NEIGHBORHOOD'].unique()
hood_names_two = two['NEIGHBORHOOD'].unique()
hood_names_three = three['NEIGHBORHOOD'].unique()

# get unique neighborhood names
groupby_hood_one = one.groupby(['NEIGHBORHOOD'])
groupby_hood_two = two.groupby(['NEIGHBORHOOD'])
groupby_hood_three = three.groupby(['NEIGHBORHOOD'])

# run the code using print(h) to get problem data and we hard code this
# this way the CVS file doesn't get modified continuously
# not enough data, to split the data 80/20
small_sample_one = ["NEW BRIGHTON-ST. GEORGE"] 
small_sample_two = ["TODT HILL", "BLOOMFIELD", "FRESH KILLS"] 
small_sample_three = ["ARDEN HEIGHTS", "HUGUENOT", "GRYMES HILL", "CLOVE LAKES", 
                "OAKWOOD-BEACH", "ELTINGVILLE", "NEW DORP-HEIGHTS", "PRINCES BAY", 
                "SILVER LAKE", "TRAVIS", "GRASMERE", "PLEASANT PLAINS", "WOODROW"]

# prediction model - ONE
dic_one = {}
for h in hood_names_one:
    temp = groupby_hood_one.get_group((h,)).copy()
    # print(h)
    if h in small_sample_one:
        dic_one[h] = temp['AVERAGE SALE PRICE'].item()
    else:
        X = temp[['YEAR', 'MEDIAN SALE PRICE', 'NUMBER OF SALES']] # independent variables table
        y = temp['AVERAGE SALE PRICE']
    
        # split the data 80/20
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
    
        # fit model
        model = LinearRegression()
        model.fit(X_train, y_train)
        
        # compare to test data
        y_pred = model.predict(X_test)
        dic_one[h] = y_pred[0]


# prediction model - TWO
dic_two = {}
for h in hood_names_two:
    temp = groupby_hood_two.get_group((h,)).copy()
    # print(h)
    if h in small_sample_two:
        dic_two[h] = temp['AVERAGE SALE PRICE'].item()
    else:
        X = temp[['YEAR', 'MEDIAN SALE PRICE', 'NUMBER OF SALES']]
        y = temp['AVERAGE SALE PRICE']
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
        model = LinearRegression()
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        dic_two[h] = y_pred[0]


# prediction model - THREE
dic_three = {}
for h in hood_names_three:
    temp = groupby_hood_three.get_group((h,)).copy()
    # print(h)
    if h in small_sample_three:
        dic_three[h] = temp['AVERAGE SALE PRICE'].item()
    else:
        X = temp[['YEAR', 'MEDIAN SALE PRICE', 'NUMBER OF SALES']]
        y = temp['AVERAGE SALE PRICE']
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
        model = LinearRegression()
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        dic_three[h] = y_pred[0]

# %% [markdown]
# ## Comparing Model to Data 2022

# %%
# loading real data
df22 = pd.read_csv("../CSV/2022.csv")
df22.drop('NUMBER OF SALES', axis=1, inplace=True)
df22.drop('LOWEST SALE PRICE', axis=1, inplace=True)
df22.drop('MEDIAN SALE PRICE', axis=1, inplace=True)
df22.drop('HIGHEST SALE PRICE', axis=1, inplace=True)
df22.drop('YEAR', axis=1, inplace=True)
test = groupby_borough = df22.groupby(['BOROUGH']).get_group(('STATEN ISLAND',)).copy()
test.drop('BOROUGH', axis=1, inplace=True)

test['PREDICT'] = "-"
test['DELTA'] = "0"

# use 3 conditionals because not all targeted neighborhoods from the 2022 may appear in 2010-2021
for i, row in test.iterrows():
    if row['TYPE OF HOME'] == '01 ONE FAMILY HOMES' and row['NEIGHBORHOOD'] in dic_one:
        test.at[i, 'PREDICT'] = int(dic_one[row['NEIGHBORHOOD']])
        test.at[i, 'DELTA'] = int(row['AVERAGE SALE PRICE']) - int(dic_one[row['NEIGHBORHOOD']])
    elif row['TYPE OF HOME'] == '02 TWO FAMILY HOMES' and row['NEIGHBORHOOD'] in dic_two:
        test.at[i, 'PREDICT'] = int(dic_two[row['NEIGHBORHOOD']])
        test.at[i, 'DELTA'] = int(row['AVERAGE SALE PRICE']) - int(dic_two[row['NEIGHBORHOOD']])
    elif row['TYPE OF HOME'] == '03 THREE FAMILY HOMES' and row['NEIGHBORHOOD'] in dic_three:
        test.at[i, 'PREDICT'] = int(dic_three[row['NEIGHBORHOOD']])
        test.at[i, 'DELTA'] = int(row['AVERAGE SALE PRICE']) - int(dic_three[row['NEIGHBORHOOD']])

# displays all 128 rows
pd.options.display.max_rows = 128
test
# Out:
#                   NEIGHBORHOOD           TYPE OF HOME  AVERAGE SALE PRICE  \
# 477                   ANNADALE    01 ONE FAMILY HOMES              954709
# 478                   ANNADALE    02 TWO FAMILY HOMES              972797
# 479                   ANNADALE  03 THREE FAMILY HOMES              995900
# 480              ARDEN HEIGHTS    01 ONE FAMILY HOMES              518603
# 481              ARDEN HEIGHTS    02 TWO FAMILY HOMES              904782
# 482                   ARROCHAR    01 ONE FAMILY HOMES              684467
# 483                   ARROCHAR    02 TWO FAMILY HOMES              744893
# 484       ARROCHAR-SHORE ACRES    01 ONE FAMILY HOMES              621032
# 485       ARROCHAR-SHORE ACRES    02 TWO FAMILY HOMES              521250
# 486                 BLOOMFIELD    01 ONE FAMILY HOMES              500000
# 487                 BULLS HEAD    01 ONE FAMILY HOMES              581310
# 488                 BULLS HEAD    02 TWO FAMILY HOMES              834128
# 489                 BULLS HEAD  03 THREE FAMILY HOMES              670000
# 490          CASTLETON CORNERS    01 ONE FAMILY HOMES              676124
# 491          CASTLETON CORNERS    02 TWO FAMILY HOMES              714829
# 492          CASTLETON CORNERS  03 THREE FAMILY HOMES              820000
# 493                CLOVE LAKES    01 ONE FAMILY HOMES              690795
# 494                CLOVE LAKES    02 TWO FAMILY HOMES              713398
# 495                    CONCORD    01 ONE FAMILY HOMES              467635
# 496                    CONCORD    02 TWO FAMILY HOMES              671554
# 497                    CONCORD  03 THREE FAMILY HOMES              581250
# 498          CONCORD-FOX HILLS    01 ONE FAMILY HOMES              505503
# 499               DONGAN HILLS    01 ONE FAMILY HOMES              682451
# 500               DONGAN HILLS    02 TWO FAMILY HOMES              902905
# 501               DONGAN HILLS  03 THREE FAMILY HOMES              505019
# 502        DONGAN HILLS-COLONY    01 ONE FAMILY HOMES             1089683
# 503        DONGAN HILLS-COLONY    02 TWO FAMILY HOMES              793476
# 504        DONGAN HILLS-COLONY  03 THREE FAMILY HOMES              908950
# 505      DONGAN HILLS-OLD TOWN    01 ONE FAMILY HOMES              534500
# 506                ELTINGVILLE    01 ONE FAMILY HOMES              711062
# 507                ELTINGVILLE    02 TWO FAMILY HOMES              885435
# 508                ELTINGVILLE  03 THREE FAMILY HOMES              950000
# 554                 PORT IVORY    01 ONE FAMILY HOMES              428204
# 555                 PORT IVORY    02 TWO FAMILY HOMES              374001
# 556              PORT RICHMOND    01 ONE FAMILY HOMES              520465
# 557              PORT RICHMOND    02 TWO FAMILY HOMES              573036
# 558              PORT RICHMOND  03 THREE FAMILY HOMES              495000
# 559                PRINCES BAY    01 ONE FAMILY HOMES              804642
# 560                PRINCES BAY    02 TWO FAMILY HOMES             1053475
# 561               RICHMONDTOWN    01 ONE FAMILY HOMES              835299
# 562               RICHMONDTOWN    02 TWO FAMILY HOMES             1038000
# 563  RICHMONDTOWN-LIGHTHS HILL    01 ONE FAMILY HOMES             1137300
# 564                   ROSEBANK    01 ONE FAMILY HOMES              612547
# 565                   ROSEBANK    02 TWO FAMILY HOMES              726894
# 566                   ROSEBANK  03 THREE FAMILY HOMES              836667
# 567                  ROSSVILLE    01 ONE FAMILY HOMES              679808
# 568                  ROSSVILLE    02 TWO FAMILY HOMES             1002584
# 569       ROSSVILLE-CHARLESTON    01 ONE FAMILY HOMES              729637
# 570       ROSSVILLE-CHARLESTON    02 TWO FAMILY HOMES             1047500
# 571  ROSSVILLE-RICHMOND VALLEY    01 ONE FAMILY HOMES              692000
# 572  ROSSVILLE-RICHMOND VALLEY    02 TWO FAMILY HOMES             1278986
# 573                SILVER LAKE    01 ONE FAMILY HOMES              759919
# 574                SILVER LAKE    02 TWO FAMILY HOMES              923000
# 575                SILVER LAKE  03 THREE FAMILY HOMES              780000
# 576                SOUTH BEACH    01 ONE FAMILY HOMES              619374
# 577                SOUTH BEACH    02 TWO FAMILY HOMES              828504
# 578                SOUTH BEACH  03 THREE FAMILY HOMES              854800
# 579                  STAPLETON    01 ONE FAMILY HOMES              436547
# 580                  STAPLETON    02 TWO FAMILY HOMES              579298
# 581                  STAPLETON  03 THREE FAMILY HOMES              660000
# 582          STAPLETON-CLIFTON    01 ONE FAMILY HOMES              620945
# 583          STAPLETON-CLIFTON    02 TWO FAMILY HOMES              630000
# 584                  SUNNYSIDE    01 ONE FAMILY HOMES              895238
# 585                  SUNNYSIDE    02 TWO FAMILY HOMES              741958
# 586                  TODT HILL    01 ONE FAMILY HOMES             1724870
# 587              TOMPKINSVILLE    01 ONE FAMILY HOMES              534969
# 588              TOMPKINSVILLE    02 TWO FAMILY HOMES              623514
# 589              TOMPKINSVILLE  03 THREE FAMILY HOMES              613333
# 590                TOTTENVILLE    01 ONE FAMILY HOMES              790047
# 591                TOTTENVILLE    02 TWO FAMILY HOMES             1056826
# 592                     TRAVIS    01 ONE FAMILY HOMES              617671
# 593                     TRAVIS    02 TWO FAMILY HOMES              757000
# 594                     TRAVIS  03 THREE FAMILY HOMES              570220
# 595          WEST NEW BRIGHTON    01 ONE FAMILY HOMES              583026
# 596          WEST NEW BRIGHTON    02 TWO FAMILY HOMES              620753
# 597          WEST NEW BRIGHTON  03 THREE FAMILY HOMES              543426
# 598                WESTERLEIGH    01 ONE FAMILY HOMES              658213
