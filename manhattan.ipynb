# %%
import pandas as pd

# %%
# reads file
df = pd.read_csv("./2010-2021.csv")
df
# Out:
#             BOROUGH   NEIGHBORHOOD           TYPE OF HOME  NUMBER OF SALES  \
# 0         MANHATTAN  ALPHABET CITY    01 ONE FAMILY HOMES                1
# 1         MANHATTAN  ALPHABET CITY    02 TWO FAMILY HOMES                1
# 2         MANHATTAN  ALPHABET CITY  03 THREE FAMILY HOMES                1
# 3         MANHATTAN        CHELSEA    01 ONE FAMILY HOMES                2
# 4         MANHATTAN        CHELSEA    02 TWO FAMILY HOMES                2
# ...             ...            ...                    ...              ...
# 7172  STATEN ISLAND    WILLOWBROOK    02 TWO FAMILY HOMES               40
# 7173  STATEN ISLAND    WILLOWBROOK  03 THREE FAMILY HOMES                1
# 7174  STATEN ISLAND        WOODROW    01 ONE FAMILY HOMES               85
# 7175  STATEN ISLAND        WOODROW    02 TWO FAMILY HOMES               51
# 7176  STATEN ISLAND        WOODROW  03 THREE FAMILY HOMES                1
#
#       LOWEST SALE PRICE  AVERAGE SALE PRICE  MEDIAN SALE PRICE  \
# ...

# %%
# gets list of column names so that there are no typos
print(df.columns.tolist())
# Out:
# ['BOROUGH', 'NEIGHBORHOOD', 'TYPE OF HOME', 'NUMBER OF SALES', 'LOWEST SALE PRICE', 'AVERAGE SALE PRICE', 'MEDIAN SALE PRICE', 'HIGHEST SALE PRICE', 'YEAR']

# %%
# gets a list of unique entries under specified column
borough = df['BOROUGH'].unique()
borough
# Out:
# array(['MANHATTAN', 'BRONX', 'BROOKLYN', 'QUEENS', 'STATEN ISLAND'],
#       dtype=object)

# %%
# create grouping of data using specified column
grouped = df.groupby(['BOROUGH'])
# creates a copy of specified entry within the column group
manhattan = grouped.get_group('MANHATTAN').copy()
manhattan
# Out:
# /var/folders/1g/j5t4q2s518533ryxlrw4rpnm0000gn/T/ipykernel_1756/2797862311.py:4: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   manhattan = grouped.get_group('MANHATTAN').copy()
#         BOROUGH              NEIGHBORHOOD           TYPE OF HOME  \
# 0     MANHATTAN             ALPHABET CITY    01 ONE FAMILY HOMES
# 1     MANHATTAN             ALPHABET CITY    02 TWO FAMILY HOMES
# 2     MANHATTAN             ALPHABET CITY  03 THREE FAMILY HOMES
# 3     MANHATTAN                   CHELSEA    01 ONE FAMILY HOMES
# 4     MANHATTAN                   CHELSEA    02 TWO FAMILY HOMES
# ...         ...                       ...                    ...
# 6615  MANHATTAN  WASHINGTON HEIGHTS LOWER    01 ONE FAMILY HOMES
# 6616  MANHATTAN  WASHINGTON HEIGHTS LOWER    02 TWO FAMILY HOMES
# ...

# %%
print(manhattan.columns.tolist())
# Out:
# ['BOROUGH', 'NEIGHBORHOOD', 'TYPE OF HOME', 'NUMBER OF SALES', 'LOWEST SALE PRICE', 'AVERAGE SALE PRICE', 'MEDIAN SALE PRICE', 'HIGHEST SALE PRICE', 'YEAR']

# %%
manhattan.drop('LOWEST SALE PRICE', axis=1, inplace=True)
manhattan.drop('HIGHEST SALE PRICE', axis=1, inplace=True)
manhattan
# Out:
#         BOROUGH              NEIGHBORHOOD           TYPE OF HOME  \
# 0     MANHATTAN             ALPHABET CITY    01 ONE FAMILY HOMES
# 1     MANHATTAN             ALPHABET CITY    02 TWO FAMILY HOMES
# 2     MANHATTAN             ALPHABET CITY  03 THREE FAMILY HOMES
# 3     MANHATTAN                   CHELSEA    01 ONE FAMILY HOMES
# 4     MANHATTAN                   CHELSEA    02 TWO FAMILY HOMES
# ...         ...                       ...                    ...
# 6615  MANHATTAN  WASHINGTON HEIGHTS LOWER    01 ONE FAMILY HOMES
# 6616  MANHATTAN  WASHINGTON HEIGHTS LOWER    02 TWO FAMILY HOMES
# 6617  MANHATTAN  WASHINGTON HEIGHTS LOWER  03 THREE FAMILY HOMES
# 6618  MANHATTAN  WASHINGTON HEIGHTS UPPER    02 TWO FAMILY HOMES
# 6619  MANHATTAN  WASHINGTON HEIGHTS UPPER  03 THREE FAMILY HOMES
#
#       NUMBER OF SALES  AVERAGE SALE PRICE  MEDIAN SALE PRICE  YEAR
# 0                   1              593362             593362  2010
# ...

# %%
# get unique groups by home type
manhattan['TYPE OF HOME'].unique()
# Out:
# array(['01 ONE FAMILY HOMES', '02 TWO FAMILY HOMES',
#        '03 THREE FAMILY HOMES'], dtype=object)

# %%
# group further by home type
home = manhattan.groupby(['TYPE OF HOME'])
one = home.get_group('01 ONE FAMILY HOMES').copy()
two = home.get_group('02 TWO FAMILY HOMES').copy()
three = home.get_group('03 THREE FAMILY HOMES').copy()
# Out:
# /var/folders/1g/j5t4q2s518533ryxlrw4rpnm0000gn/T/ipykernel_1756/1370897903.py:3: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   one = home.get_group('01 ONE FAMILY HOMES').copy()
# /var/folders/1g/j5t4q2s518533ryxlrw4rpnm0000gn/T/ipykernel_1756/1370897903.py:4: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   two = home.get_group('02 TWO FAMILY HOMES').copy()
# /var/folders/1g/j5t4q2s518533ryxlrw4rpnm0000gn/T/ipykernel_1756/1370897903.py:5: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# ...

# %%
temp = one['NEIGHBORHOOD'].unique()
hood = one.groupby(['NEIGHBORHOOD'])
hood.get_group('ALPHABET CITY').copy()
one.groupby(['NEIGHBORHOOD']).count()
# Out:
# /var/folders/1g/j5t4q2s518533ryxlrw4rpnm0000gn/T/ipykernel_1756/2861602461.py:3: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   hood.get_group('ALPHABET CITY').copy()
#                            BOROUGH  TYPE OF HOME  NUMBER OF SALES  \
# NEIGHBORHOOD
# ALPHABET CITY                    5             5                5
# CHELSEA                         11            11               11
# CLINTON                          2             2                2
# EAST VILLAGE                     6             6                6
# GRAMERCY                         7             7                7
# GREENWICH VILLAGE-CENTRAL       12            12               12
# GREENWICH VILLAGE-WEST          12            12               12
# HARLEM-CENTRAL                  12            12               12
# ...

# %%
temp
# Out:
# array(['ALPHABET CITY', 'CHELSEA', 'CLINTON', 'EAST VILLAGE', 'GRAMERCY',
#        'GREENWICH VILLAGE-CENTRAL', 'GREENWICH VILLAGE-WEST',
#        'HARLEM-CENTRAL', 'HARLEM-UPPER', 'INWOOD', 'LITTLE ITALY',
#        'MIDTOWN EAST', 'MURRAY HILL', 'SOHO', 'SOUTHBRIDGE', 'TRIBECA',
#        'UPPER EAST SIDE (59-79)', 'UPPER EAST SIDE (79-96)',
#        'UPPER WEST SIDE (59-79)', 'UPPER WEST SIDE (79-96)',
#        'UPPER WEST SIDE (96-116)', 'WASHINGTON HEIGHTS LOWER', 'KIPS BAY',
#        'HARLEM-EAST', 'MANHATTAN VALLEY', 'WASHINGTON HEIGHTS UPPER',
#        'HARLEM-WEST', 'LOWER EAST SIDE'], dtype=object)

# %%
dic = {}
for h in temp:
    print(hood.get_group(h).copy())
# Out:
#         BOROUGH   NEIGHBORHOOD         TYPE OF HOME  NUMBER OF SALES  \
# 0     MANHATTAN  ALPHABET CITY  01 ONE FAMILY HOMES                1
# 2971  MANHATTAN  ALPHABET CITY  01 ONE FAMILY HOMES                1
# 4777  MANHATTAN  ALPHABET CITY  01 ONE FAMILY HOMES                2
# 5378  MANHATTAN  ALPHABET CITY  01 ONE FAMILY HOMES                1
# 6562  MANHATTAN  ALPHABET CITY  01 ONE FAMILY HOMES                1
#
#       AVERAGE SALE PRICE  MEDIAN SALE PRICE  YEAR
# 0                 593362             593362  2010
# 2971             6500000            6500000  2015
# 4777             5472405            5472405  2018
# 5378             3200000            3200000  2019
# 6562             2385000            2385000  2021
#         BOROUGH NEIGHBORHOOD         TYPE OF HOME  NUMBER OF SALES  \
# 3     MANHATTAN      CHELSEA  01 ONE FAMILY HOMES                2
# 587   MANHATTAN      CHELSEA  01 ONE FAMILY HOMES                2
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
dic = {}
for h in temp:
    temp2 = hood.get_group(h).copy()
    X = temp2[['YEAR', 'MEDIAN SALE PRICE', 'NUMBER OF SALES']] # independent variables table
    y = temp2['AVERAGE SALE PRICE']
    # print(f'{X}')
    # split the data 80/20
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
    # print(f"test: {y_test}  \npred:{y_pred}")
    # fit model
    model = LinearRegression()
    model.fit(X_train, y_train)
    
    # compare to test data
    y_pred = model.predict(X_test)
    dic[h] = y_pred[0]

    # test 80 to 20 accuracy
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    
    print(f'{h} - Mean Squared Error: {mse}')
    print(f'{h} - r2: {r2}')
# Out:
# ALPHABET CITY - Mean Squared Error: 3.469446951953614e-18
# ALPHABET CITY - r2: nan
# CHELSEA - Mean Squared Error: 89489866195.52199
# CHELSEA - r2: 0.9927625546202706
# CLINTON - Mean Squared Error: 13322500000000.0
# CLINTON - r2: nan
# EAST VILLAGE - Mean Squared Error: 3864199999999.705
# EAST VILLAGE - r2: 0.11535908060719646
# GRAMERCY - Mean Squared Error: 1.0842021724855044e-19
# GRAMERCY - r2: 1.0
# GREENWICH VILLAGE-CENTRAL - Mean Squared Error: 4557793869208.0205
# GREENWICH VILLAGE-CENTRAL - r2: -0.0525500418341216
# GREENWICH VILLAGE-WEST - Mean Squared Error: 8071007486847.983
# GREENWICH VILLAGE-WEST - r2: -6.341667248335097
# HARLEM-CENTRAL - Mean Squared Error: 78330627316.1221
# HARLEM-CENTRAL - r2: 0.36492231542736797
# HARLEM-UPPER - Mean Squared Error: 75782553119.65565
# HARLEM-UPPER - r2: 0.7841922422397429
# INWOOD - Mean Squared Error: 2816211542.395512
# INWOOD - r2: 0.8959913400682556
# LITTLE ITALY - Mean Squared Error: 1.3877787807814457e-17
# ...

# %%
# Out:
# Mean Squared Error: 1325107039695.5298
# R-squared: 0.9544704908242749
