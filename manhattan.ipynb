# %%
import pandas as pd

# %%
df = pd.read_csv("./2010-2023.csv")
df
# Out:
#             BOROUGH   NEIGHBORHOOD           TYPE OF HOME  NUMBER OF SALES  \
# 0         MANHATTAN  ALPHABET CITY    01 ONE FAMILY HOMES                1
# 1         MANHATTAN  ALPHABET CITY    02 TWO FAMILY HOMES                1
# 2         MANHATTAN  ALPHABET CITY  03 THREE FAMILY HOMES                1
# 3         MANHATTAN        CHELSEA    01 ONE FAMILY HOMES                2
# 4         MANHATTAN        CHELSEA    02 TWO FAMILY HOMES                2
# ...             ...            ...                    ...              ...
# 7780  STATEN ISLAND    WESTERLEIGH  03 THREE FAMILY HOMES                1
# 7781  STATEN ISLAND    WILLOWBROOK    01 ONE FAMILY HOMES               81
# 7782  STATEN ISLAND    WILLOWBROOK    02 TWO FAMILY HOMES               42
# 7783  STATEN ISLAND        WOODROW    01 ONE FAMILY HOMES               53
# 7784  STATEN ISLAND        WOODROW    02 TWO FAMILY HOMES               56
#
#       LOWEST SALE PRICE  AVERAGE SALE PRICE  MEDIAN SALE PRICE  \
# ...

# %%
print(df.columns.tolist())
# Out:
# ['BOROUGH', 'NEIGHBORHOOD', 'TYPE OF HOME', 'NUMBER OF SALES', 'LOWEST SALE PRICE', 'AVERAGE SALE PRICE', 'MEDIAN SALE PRICE', 'HIGHEST SALE PRICE', 'YEAR']

# %%
borough = df['BOROUGH'].unique()
borough
# Out:
# array(['MANHATTAN', 'BRONX', 'BROOKLYN', 'QUEENS', 'STATEN ISLAND'],
#       dtype=object)

# %%
grouped = df.groupby(['BOROUGH'])
manhattan = grouped.get_group('MANHATTAN').copy()
manhattan
# Out:
# /var/folders/1g/j5t4q2s518533ryxlrw4rpnm0000gn/T/ipykernel_8572/55429827.py:2: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   manhattan = grouped.get_group('MANHATTAN').copy()
#         BOROUGH              NEIGHBORHOOD           TYPE OF HOME  \
# 0     MANHATTAN             ALPHABET CITY    01 ONE FAMILY HOMES
# 1     MANHATTAN             ALPHABET CITY    02 TWO FAMILY HOMES
# 2     MANHATTAN             ALPHABET CITY  03 THREE FAMILY HOMES
# 3     MANHATTAN                   CHELSEA    01 ONE FAMILY HOMES
# 4     MANHATTAN                   CHELSEA    02 TWO FAMILY HOMES
# ...         ...                       ...                    ...
# 7492  MANHATTAN   UPPER WEST SIDE (79-96)  03 THREE FAMILY HOMES
# 7493  MANHATTAN  WASHINGTON HEIGHTS LOWER    01 ONE FAMILY HOMES
# ...

# %%
print(mahattan.columns.tolist())
# Out:
# ['BOROUGH', 'NEIGHBORHOOD', 'TYPE OF HOME', 'NUMBER OF SALES', 'AVERAGE SALE PRICE', 'MEDIAN SALE PRICE']

# %%
manhattan.drop('LOWEST SALE PRICE', axis=1, inplace=True)
manhattan.drop('HIGHEST SALE PRICE', axis=1, inplace=True)
manhattan.drop('YEAR', axis=1, inplace=True)
manhattan
# Out:
#         BOROUGH              NEIGHBORHOOD           TYPE OF HOME  \
# 0     MANHATTAN             ALPHABET CITY    01 ONE FAMILY HOMES
# 1     MANHATTAN             ALPHABET CITY    02 TWO FAMILY HOMES
# 2     MANHATTAN             ALPHABET CITY  03 THREE FAMILY HOMES
# 3     MANHATTAN                   CHELSEA    01 ONE FAMILY HOMES
# 4     MANHATTAN                   CHELSEA    02 TWO FAMILY HOMES
# ...         ...                       ...                    ...
# 7492  MANHATTAN   UPPER WEST SIDE (79-96)  03 THREE FAMILY HOMES
# 7493  MANHATTAN  WASHINGTON HEIGHTS LOWER    01 ONE FAMILY HOMES
# 7494  MANHATTAN  WASHINGTON HEIGHTS LOWER    02 TWO FAMILY HOMES
# 7495  MANHATTAN  WASHINGTON HEIGHTS LOWER  03 THREE FAMILY HOMES
# 7496  MANHATTAN  WASHINGTON HEIGHTS UPPER    01 ONE FAMILY HOMES
#
#       NUMBER OF SALES  AVERAGE SALE PRICE  MEDIAN SALE PRICE
# 0                   1              593362             593362
# 1                   1             1320000            1320000
# ...

# %%
types = manhattan['TYPE OF HOME'].unique()
types
# Out:
# array(['01 ONE FAMILY HOMES', '02 TWO FAMILY HOMES',
#        '03 THREE FAMILY HOMES'], dtype=object)

# %%
grouped = manhattan.groupby(['TYPE OF HOME'])
one = grouped.get_group('01 ONE FAMILY HOMES').copy()
two = grouped.get_group('02 TWO FAMILY HOMES').copy()
three = grouped.get_group('03 THREE FAMILY HOMES').copy()
one
# Out:
# /var/folders/1g/j5t4q2s518533ryxlrw4rpnm0000gn/T/ipykernel_8572/4036322705.py:2: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   one = grouped.get_group('01 ONE FAMILY HOMES').copy()
# /var/folders/1g/j5t4q2s518533ryxlrw4rpnm0000gn/T/ipykernel_8572/4036322705.py:3: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   two = grouped.get_group('02 TWO FAMILY HOMES').copy()
# /var/folders/1g/j5t4q2s518533ryxlrw4rpnm0000gn/T/ipykernel_8572/4036322705.py:4: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# ...
