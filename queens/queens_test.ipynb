# %% [markdown]
# ## Loading Data 2010-2021

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# loading data
df = pd.read_csv("../CSV/2010-2021.csv")
# drop unused columns
df.drop('LOWEST SALE PRICE', axis=1, inplace=True)
df.drop('HIGHEST SALE PRICE', axis=1, inplace=True)
# create grouping of data using specified column then
# creates a copy of specified entry within the column group
borough = groupby_borough = df.groupby(['BOROUGH']).get_group(('QUEENS',)).copy()

# group further by home type
groupby_home = borough.groupby(['TYPE OF HOME'])
one = groupby_home.get_group(('01 ONE FAMILY HOMES',)).copy()
two = groupby_home.get_group(('02 TWO FAMILY HOMES',)).copy()
three = groupby_home.get_group(('03 THREE FAMILY HOMES',)).copy()

# %% [markdown]
# ## Setting up Model

# %%
# group home type into neighborhood
hood_names_one = one['NEIGHBORHOOD'].unique()
hood_names_two = two['NEIGHBORHOOD'].unique()
hood_names_three = three['NEIGHBORHOOD'].unique()

# get unique neighborhood names
groupby_hood_one = one.groupby(['NEIGHBORHOOD'])
groupby_hood_two = two.groupby(['NEIGHBORHOOD'])
groupby_hood_three = three.groupby(['NEIGHBORHOOD'])

# run the code using print(h) to get problem data and we hard code this
# this way the CVS file doesn't get modified continuously
# not enough data, to split the data 80/20
small_sample_one = ["QUEENS-UNKNOWN"]
small_sample_two = ["QUEENS-UNKNOWN"] 
small_sample_three = ["NEPONSIT", "JAMAICA BAY"] 

# prediction model - ONE
dic_one = {}
for h in hood_names_one:
    temp = groupby_hood_one.get_group((h,)).copy()
    # print(h)
    if h in small_sample_one:
        dic_one[h] = temp['AVERAGE SALE PRICE'].item()
    else:
        X = temp[['YEAR', 'MEDIAN SALE PRICE', 'NUMBER OF SALES']] # independent variables table
        y = temp['AVERAGE SALE PRICE']
    
        # split the data 80/20
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
    
        # fit model
        model = LinearRegression()
        model.fit(X_train, y_train)
        
        # compare to test data
        y_pred = model.predict(X_test)
        dic_one[h] = y_pred[0]


# prediction model - TWO
dic_two = {}
for h in hood_names_two:
    temp = groupby_hood_two.get_group((h,)).copy()
    # print(h)
    if h in small_sample_two:
        dic_two[h] = temp['AVERAGE SALE PRICE'].item()
    else:
        X = temp[['YEAR', 'MEDIAN SALE PRICE', 'NUMBER OF SALES']]
        y = temp['AVERAGE SALE PRICE']
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
        model = LinearRegression()
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        dic_two[h] = y_pred[0]


# prediction model - THREE
dic_three = {}
for h in hood_names_three:
    temp = groupby_hood_three.get_group((h,)).copy()
    # print(h)
    if h in small_sample_three:
        dic_three[h] = temp['AVERAGE SALE PRICE'].item()
    else:
        X = temp[['YEAR', 'MEDIAN SALE PRICE', 'NUMBER OF SALES']]
        y = temp['AVERAGE SALE PRICE']
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
        model = LinearRegression()
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        dic_three[h] = y_pred[0]

# %% [markdown]
# ## Comparing Model to Data 2022

# %%
# loading real data
df22 = pd.read_csv("../CSV/2022.csv")
df22.drop('NUMBER OF SALES', axis=1, inplace=True)
df22.drop('LOWEST SALE PRICE', axis=1, inplace=True)
df22.drop('MEDIAN SALE PRICE', axis=1, inplace=True)
df22.drop('HIGHEST SALE PRICE', axis=1, inplace=True)
df22.drop('YEAR', axis=1, inplace=True)
test = groupby_borough = df22.groupby(['BOROUGH']).get_group(('QUEENS',)).copy()
test.drop('BOROUGH', axis=1, inplace=True)

test['PREDICT'] = "-"
test['DELTA'] = "0"

# use 3 conditionals because not all targeted neighborhoods from the 2022 may appear in 2010-2021
for i, row in test.iterrows():
    if row['TYPE OF HOME'] == '01 ONE FAMILY HOMES' and row['NEIGHBORHOOD'] in dic_one:
        test.at[i, 'PREDICT'] = int(dic_one[row['NEIGHBORHOOD']])
        test.at[i, 'DELTA'] = int(row['AVERAGE SALE PRICE']) - int(dic_one[row['NEIGHBORHOOD']])
    elif row['TYPE OF HOME'] == '02 TWO FAMILY HOMES' and row['NEIGHBORHOOD'] in dic_two:
        test.at[i, 'PREDICT'] = int(dic_two[row['NEIGHBORHOOD']])
        test.at[i, 'DELTA'] = int(row['AVERAGE SALE PRICE']) - int(dic_two[row['NEIGHBORHOOD']])
    elif row['TYPE OF HOME'] == '03 THREE FAMILY HOMES' and row['NEIGHBORHOOD'] in dic_three:
        test.at[i, 'PREDICT'] = int(dic_three[row['NEIGHBORHOOD']])
        test.at[i, 'DELTA'] = int(row['AVERAGE SALE PRICE']) - int(dic_three[row['NEIGHBORHOOD']])

# displays all 160 rows
pd.options.display.max_rows = 160
test
# Out:
#                  NEIGHBORHOOD           TYPE OF HOME  AVERAGE SALE PRICE  \
# 317        AIRPORT LA GUARDIA    01 ONE FAMILY HOMES              852299
# 318                   ARVERNE    01 ONE FAMILY HOMES              514303
# 319                   ARVERNE    02 TWO FAMILY HOMES              757319
# 320                   ARVERNE  03 THREE FAMILY HOMES              845698
# 321                   ASTORIA    01 ONE FAMILY HOMES             1241253
# 322                   ASTORIA    02 TWO FAMILY HOMES             1286027
# 323                   ASTORIA  03 THREE FAMILY HOMES             1424063
# 324                   BAYSIDE    01 ONE FAMILY HOMES             1059750
# 325                   BAYSIDE    02 TWO FAMILY HOMES             1441296
# 326                   BAYSIDE  03 THREE FAMILY HOMES             1393111
# 327                BEECHHURST    01 ONE FAMILY HOMES             1138755
# 328                BEECHHURST    02 TWO FAMILY HOMES             1386667
# 329              BELLE HARBOR    01 ONE FAMILY HOMES             1167630
# 330              BELLE HARBOR    02 TWO FAMILY HOMES             1103370
# 331              BELLE HARBOR  03 THREE FAMILY HOMES              780000
# 332                 BELLEROSE    01 ONE FAMILY HOMES              754749
# 333                 BELLEROSE    02 TWO FAMILY HOMES              843967
# 334                 BELLEROSE  03 THREE FAMILY HOMES             1113833
# 335              BREEZY POINT    01 ONE FAMILY HOMES              762229
# 336                 BRIARWOOD    01 ONE FAMILY HOMES              813570
# 337                 BRIARWOOD    02 TWO FAMILY HOMES             1031882
# 338                 BRIARWOOD  03 THREE FAMILY HOMES             1187838
# 339             BROAD CHANNEL    01 ONE FAMILY HOMES              575026
# 340           CAMBRIA HEIGHTS    01 ONE FAMILY HOMES              610884
# 341           CAMBRIA HEIGHTS    02 TWO FAMILY HOMES              782273
# 342           CAMBRIA HEIGHTS  03 THREE FAMILY HOMES              510000
# 343             COLLEGE POINT    01 ONE FAMILY HOMES              875646
# 344             COLLEGE POINT    02 TWO FAMILY HOMES             1026910
# 345             COLLEGE POINT  03 THREE FAMILY HOMES             1099241
# 346                    CORONA    01 ONE FAMILY HOMES              937720
# 347                    CORONA    02 TWO FAMILY HOMES             1071234
# 348                    CORONA  03 THREE FAMILY HOMES             1327392
# 349                DOUGLASTON    01 ONE FAMILY HOMES             1297075
# 350                DOUGLASTON    02 TWO FAMILY HOMES             1450917
# 351             EAST ELMHURST    01 ONE FAMILY HOMES              748024
# 352             EAST ELMHURST    02 TWO FAMILY HOMES             1053154
# 353             EAST ELMHURST  03 THREE FAMILY HOMES             1199091
# 354                  ELMHURST    01 ONE FAMILY HOMES             1009013
# 355                  ELMHURST    02 TWO FAMILY HOMES             1075002
# 356                  ELMHURST  03 THREE FAMILY HOMES             1390827
# 357              FAR ROCKAWAY    01 ONE FAMILY HOMES              751618
# 358              FAR ROCKAWAY    02 TWO FAMILY HOMES              691935
# 359              FAR ROCKAWAY  03 THREE FAMILY HOMES              731831
# 360               FLORAL PARK    01 ONE FAMILY HOMES              799966
# 361               FLORAL PARK    02 TWO FAMILY HOMES              974000
# 362               FLORAL PARK  03 THREE FAMILY HOMES              995000
# 363      FLUSHING MEADOW PARK  03 THREE FAMILY HOMES             1572000
# 364            FLUSHING-NORTH    01 ONE FAMILY HOMES             1060208
# 365            FLUSHING-NORTH    02 TWO FAMILY HOMES             1274627
# 366            FLUSHING-NORTH  03 THREE FAMILY HOMES             1612256
# 367            FLUSHING-SOUTH    01 ONE FAMILY HOMES              977874
# 368            FLUSHING-SOUTH    02 TWO FAMILY HOMES             1110390
# 369            FLUSHING-SOUTH  03 THREE FAMILY HOMES             1439035
# 370              FOREST HILLS    01 ONE FAMILY HOMES             1513391
# 371              FOREST HILLS    02 TWO FAMILY HOMES             1310429
# 372              FOREST HILLS  03 THREE FAMILY HOMES             1532667
# 373             FRESH MEADOWS    01 ONE FAMILY HOMES             1098746
# 374             FRESH MEADOWS    02 TWO FAMILY HOMES             1058667
# 375                 GLEN OAKS    01 ONE FAMILY HOMES              810995
# 376                 GLEN OAKS    02 TWO FAMILY HOMES             1513000
# 377                 GLEN OAKS  03 THREE FAMILY HOMES              810000
# 378                  GLENDALE    01 ONE FAMILY HOMES              782107
# 379                  GLENDALE    02 TWO FAMILY HOMES              883612
# 380                  GLENDALE  03 THREE FAMILY HOMES             1197091
# 381                   HAMMELS    01 ONE FAMILY HOMES              610833
# 382                   HAMMELS    02 TWO FAMILY HOMES              915586
# 383                   HAMMELS  03 THREE FAMILY HOMES             1036358
# 384                 HILLCREST    01 ONE FAMILY HOMES              825025
# 385                 HILLCREST    02 TWO FAMILY HOMES              812600
# 386                    HOLLIS    01 ONE FAMILY HOMES              713610
# 387                    HOLLIS    02 TWO FAMILY HOMES              762625
# 388                    HOLLIS  03 THREE FAMILY HOMES             1001667
# 389              HOLLIS HILLS    01 ONE FAMILY HOMES             1189268
# 390              HOLLIS HILLS    02 TWO FAMILY HOMES             1130000
# 391                HOLLISWOOD    01 ONE FAMILY HOMES             1218311
# 392                HOLLISWOOD    02 TWO FAMILY HOMES              995000
# 393              HOWARD BEACH    01 ONE FAMILY HOMES              839467
# 394              HOWARD BEACH    02 TWO FAMILY HOMES              921155
# 395              HOWARD BEACH  03 THREE FAMILY HOMES             1037600
# 396           JACKSON HEIGHTS    01 ONE FAMILY HOMES              904369
# 397           JACKSON HEIGHTS    02 TWO FAMILY HOMES             1110572
# 398           JACKSON HEIGHTS  03 THREE FAMILY HOMES             1280151
# 399                   JAMAICA    01 ONE FAMILY HOMES              784160
# 400                   JAMAICA    02 TWO FAMILY HOMES              945266
# 401                   JAMAICA  03 THREE FAMILY HOMES             1166200
# 402               JAMAICA BAY    01 ONE FAMILY HOMES              633819
# 403               JAMAICA BAY    02 TWO FAMILY HOMES              602408
# 404           JAMAICA ESTATES    01 ONE FAMILY HOMES             1335184
# 405           JAMAICA ESTATES    02 TWO FAMILY HOMES             1013333
# 406             JAMAICA HILLS    01 ONE FAMILY HOMES              805213
# 407             JAMAICA HILLS    02 TWO FAMILY HOMES              793867
# 408             JAMAICA HILLS  03 THREE FAMILY HOMES             1210000
# 409               KEW GARDENS    01 ONE FAMILY HOMES             1150974
# 410               KEW GARDENS    02 TWO FAMILY HOMES             1082000
# 411               KEW GARDENS  03 THREE FAMILY HOMES             1262193
# 412                 LAURELTON    01 ONE FAMILY HOMES              631955
# 413                 LAURELTON    02 TWO FAMILY HOMES              796302
# 414               LITTLE NECK    01 ONE FAMILY HOMES             1091274
# 415               LITTLE NECK    02 TWO FAMILY HOMES             1312903
# 416          LONG ISLAND CITY    01 ONE FAMILY HOMES              881400
# 417          LONG ISLAND CITY    02 TWO FAMILY HOMES             1612910
# 418          LONG ISLAND CITY  03 THREE FAMILY HOMES             1473083
# 419                   MASPETH    01 ONE FAMILY HOMES              789655
# 420                   MASPETH    02 TWO FAMILY HOMES              953636
# 421                   MASPETH  03 THREE FAMILY HOMES             1229271
# 422            MIDDLE VILLAGE    01 ONE FAMILY HOMES              828213
# 423            MIDDLE VILLAGE    02 TWO FAMILY HOMES              987359
# 424            MIDDLE VILLAGE  03 THREE FAMILY HOMES             1305251
# 425                  NEPONSIT    01 ONE FAMILY HOMES             1271242
# 426           OAKLAND GARDENS    01 ONE FAMILY HOMES             1076223
# 427           OAKLAND GARDENS    02 TWO FAMILY HOMES             1813079
# 428           OAKLAND GARDENS  03 THREE FAMILY HOMES             1303633
# 429                OZONE PARK    01 ONE FAMILY HOMES              664503
# 430                OZONE PARK    02 TWO FAMILY HOMES              846317
# 431                OZONE PARK  03 THREE FAMILY HOMES              945980
# 432            QUEENS VILLAGE    01 ONE FAMILY HOMES              652472
# 433            QUEENS VILLAGE    02 TWO FAMILY HOMES              761764
# 434            QUEENS VILLAGE  03 THREE FAMILY HOMES              902500
# 435                 REGO PARK    01 ONE FAMILY HOMES              941065
# 436                 REGO PARK    02 TWO FAMILY HOMES             1311077
# 437                 REGO PARK  03 THREE FAMILY HOMES             1423833
# 438             RICHMOND HILL    01 ONE FAMILY HOMES              676543
# 439             RICHMOND HILL    02 TWO FAMILY HOMES              839231
# 440             RICHMOND HILL  03 THREE FAMILY HOMES              969008
# 441                 RIDGEWOOD    01 ONE FAMILY HOMES              856102
# 442                 RIDGEWOOD    02 TWO FAMILY HOMES             1100603
# 443                 RIDGEWOOD  03 THREE FAMILY HOMES             1258391
# 444             ROCKAWAY PARK    01 ONE FAMILY HOMES              824667
# 445             ROCKAWAY PARK    02 TWO FAMILY HOMES              998333
# 446             ROCKAWAY PARK  03 THREE FAMILY HOMES              829500
# 447                  ROSEDALE    01 ONE FAMILY HOMES              644633
# 448                  ROSEDALE    02 TWO FAMILY HOMES              843302
# 449                  ROSEDALE  03 THREE FAMILY HOMES              903541
# 450  SO. JAMAICA-BAISLEY PARK    01 ONE FAMILY HOMES              584631
# 451  SO. JAMAICA-BAISLEY PARK    02 TWO FAMILY HOMES              761424
# 452  SO. JAMAICA-BAISLEY PARK  03 THREE FAMILY HOMES              550000
# 453             SOUTH JAMAICA    01 ONE FAMILY HOMES              573821
# 454             SOUTH JAMAICA    02 TWO FAMILY HOMES              762773
# 455             SOUTH JAMAICA  03 THREE FAMILY HOMES              773464
# 456          SOUTH OZONE PARK    01 ONE FAMILY HOMES              653423
# 457          SOUTH OZONE PARK    02 TWO FAMILY HOMES              848425
# 458          SOUTH OZONE PARK  03 THREE FAMILY HOMES              953920
# 459       SPRINGFIELD GARDENS    01 ONE FAMILY HOMES              616412
# 460       SPRINGFIELD GARDENS    02 TWO FAMILY HOMES              818832
# 461       SPRINGFIELD GARDENS  03 THREE FAMILY HOMES              746600
# 462                ST. ALBANS    01 ONE FAMILY HOMES              635420
# 463                ST. ALBANS    02 TWO FAMILY HOMES              749394
# 464                ST. ALBANS  03 THREE FAMILY HOMES              630750
# 465                 SUNNYSIDE    01 ONE FAMILY HOMES             1227400
# 466                 SUNNYSIDE    02 TWO FAMILY HOMES             1402531
# 467                 SUNNYSIDE  03 THREE FAMILY HOMES             1391667
# 468                WHITESTONE    01 ONE FAMILY HOMES             1198049
# 469                WHITESTONE    02 TWO FAMILY HOMES             1418824
# 470                WHITESTONE  03 THREE FAMILY HOMES             1809000
# 471                 WOODHAVEN    01 ONE FAMILY HOMES              672759
# 472                 WOODHAVEN    02 TWO FAMILY HOMES              880278
# 473                 WOODHAVEN  03 THREE FAMILY HOMES              876953
# 474                  WOODSIDE    01 ONE FAMILY HOMES              825112
# 475                  WOODSIDE    02 TWO FAMILY HOMES             1127911
# 476                  WOODSIDE  03 THREE FAMILY HOMES             1196846
#
#      PREDICT    DELTA
# 317   623949   228350
# 318   364046   150257
# 319   572543   184776
# 320   600090   245608
# 321   947997   293256
# 322  1032495   253532
# 323  1157363   266700
# 324   823687   236063
# 325   981854   459442
# 326  1065671   327440
# 327   970537   168218
# 328   819094   567573
# 329   837978   329652
# 330   771547   331823
# 331  1141534  -361534
# 332   542833   211916
# 333   548441   295526
# 334   298466   815367
# 335   629310   132919
# 336   603735   209835
# 337   707473   324409
# 338   569417   618421
# 339   377319   197707
# 340   391840   219044
# 341   465663   316610
# 342        -        0
# 343   650472   225174
# 344   820294   206616
# 345   967363   131878
# 346   847651    90069
# 347   786758   284476
# 348   969125   358267
# 349  1106420   190655
# 350  1001869   449048
# 351   541121   206903
# 352   724883   328271
# 353   737812   461279
# 354   731199   277814
# 355   878188   196814
# 356   988114   402713
# 357   526346   225272
# 358  -737277  1429212
# 359   441781   290050
# 360   584012   215954
# 361   740911   233089
# 362   817500   177500
# 363   700000   872000
# 364   824408   235800
# 365   969920   304707
# 366  1224357   387899
# 367   733615   244259
# 368   798072   312318
# 369  1102248   336787
# 370  1163120   350271
# 371   975491   334938
# 372  1070399   462268
# 373   838059   260687
# 374   860269   198398
# 375   586025   224970
# 376   859112   653888
# 377   998000  -188000
# 378   593729   188378
# 379   702200   181412
# 380   865690   331401
# 381   385785   225048
# 382   431461   484125
# 383   373471   662887
# 384   622030   202995
# 385   602182   210418
# 386   422923   290687
# 387   490407   272218
# 388   587840   413827
# 389   907178   282090
# 390   675000   455000
# 391   856923   361388
# 392   680005   314995
# 393   580843   258624
# 394   660504   260651
# 395   729691   307909
# 396   652801   251568
# 397   784127   326445
# 398   941461   338690
# 399   499241   284919
# 400   701223   244043
# 401   798559   367641
# 402   370822   262997
# 403   480261   122147
# 404  1091073   244111
# 405   962461    50872
# 406   652560   152653
# 407   663408   130459
# 408   776687   433313
# 409   818566   332408
# 410   654126   427874
# 411   897892   364301
# 412   406345   225610
# 413   499555   296747
# 414   886603   204671
# 415  1076322   236581
# 416   984841  -103441
# 417  1347625   265285
# 418  1569330   -96247
# 419   582343   207312
# 420   696292   257344
# 421   890902   338369
# 422   649886   178327
# 423   788839   198520
# 424   857741   447510
# 425   997102   274140
# 426   831129   245094
# 427  1315409   497670
# 428   967442   336191
# 429   443308   221195
# 430   557015   289302
# 431   637368   308612
# 432   445440   207032
# 433   551767   209997
# 434   735186   167314
# 435   862030    79035
# 436   921543   389534
# 437  1168854   254979
# 438   452589   223954
# 439   525082   314149
# 440   615074   353934
# 441   738022   118080
# 442   852615   247988
# 443   959137   299254
# 444   518846   305821
# 445   584104   414229
# 446   481712   347788
# 447   403416   241217
# 448   545808   297494
# 449   510710   392831
# 450   361827   222804
# 451   527343   234081
# 452   522468    27532
# 453   372264   201557
# 454   463771   299002
# 455   518138   255326
# 456   430596   222827
# 457   544444   303981
# 458   451845   502075
# 459   378196   238216
# 460   514011   304821
# 461   372007   374593
# 462   394308   241112
# 463   482620   266774
# 464   512452   118298
# 465   849663   377737
# 466   938400   464131
# 467  1018138   373529
# 468   874350   323699
# 469   989336   429488
# 470  1155263   653737
# 471   458245   214514
# 472   633995   246283
# 473   656900   220053
# 474   679765   145347
# 475   876096   251815
# 476  1089998   106848
