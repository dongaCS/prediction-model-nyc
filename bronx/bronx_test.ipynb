# %% [markdown]
# ## Loading Data 2010-2021

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# loading data
df = pd.read_csv("../CSV/2010-2021.csv")
# drop unused columns
df.drop('LOWEST SALE PRICE', axis=1, inplace=True)
df.drop('HIGHEST SALE PRICE', axis=1, inplace=True)
# create grouping of data using specified column then
# creates a copy of specified entry within the column group
borough = groupby_borough = df.groupby(['BOROUGH']).get_group(('BRONX',)).copy()

# group further by home type
groupby_home = borough.groupby(['TYPE OF HOME'])
one = groupby_home.get_group(('01 ONE FAMILY HOMES',)).copy()
two = groupby_home.get_group(('02 TWO FAMILY HOMES',)).copy()
three = groupby_home.get_group(('03 THREE FAMILY HOMES',)).copy()

# %% [markdown]
# ## Setting up Model

# %%
# group home type into neighborhood
hood_names_one = one['NEIGHBORHOOD'].unique()
hood_names_two = two['NEIGHBORHOOD'].unique()
hood_names_three = three['NEIGHBORHOOD'].unique()

# get unique neighborhood names
groupby_hood_one = one.groupby(['NEIGHBORHOOD'])
groupby_hood_two = two.groupby(['NEIGHBORHOOD'])
groupby_hood_three = three.groupby(['NEIGHBORHOOD'])

# run the code using print(h) to get problem data and we hard code this
# this way the CVS file doesn't get modified continuously
# not enough data, to split the data 80/20
small_sample_one = []
small_sample_two = [] 
small_sample_three = []

# prediction model - ONE
dic_one = {}
for h in hood_names_one:
    temp = groupby_hood_one.get_group((h,)).copy()
    # print(h)
    if h in small_sample_one:
        dic_one[h] = temp['AVERAGE SALE PRICE'].item()
    else:
        X = temp[['YEAR', 'MEDIAN SALE PRICE', 'NUMBER OF SALES']] # independent variables table
        y = temp['AVERAGE SALE PRICE']
    
        # split the data 80/20
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
    
        # fit model
        model = LinearRegression()
        model.fit(X_train, y_train)
        
        # compare to test data
        y_pred = model.predict(X_test)
        dic_one[h] = y_pred[0]


# prediction model - TWO
dic_two = {}
for h in hood_names_two:
    temp = groupby_hood_two.get_group((h,)).copy()
    # print(h)
    if h in small_sample_two:
        dic_two[h] = temp['AVERAGE SALE PRICE'].item()
    else:
        X = temp[['YEAR', 'MEDIAN SALE PRICE', 'NUMBER OF SALES']]
        y = temp['AVERAGE SALE PRICE']
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
        model = LinearRegression()
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        dic_two[h] = y_pred[0]


# prediction model - THREE
dic_three = {}
for h in hood_names_three:
    temp = groupby_hood_three.get_group((h,)).copy()
    # print(h)
    if h in small_sample_three:
        dic_three[h] = temp['AVERAGE SALE PRICE'].item()
    else:
        X = temp[['YEAR', 'MEDIAN SALE PRICE', 'NUMBER OF SALES']]
        y = temp['AVERAGE SALE PRICE']
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
        model = LinearRegression()
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        dic_three[h] = y_pred[0]

# %% [markdown]
# ## Comparing Model to Data 2022

# %%
# loading real data
df22 = pd.read_csv("../CSV/2022.csv")
df22.drop('NUMBER OF SALES', axis=1, inplace=True)
df22.drop('LOWEST SALE PRICE', axis=1, inplace=True)
df22.drop('MEDIAN SALE PRICE', axis=1, inplace=True)
df22.drop('HIGHEST SALE PRICE', axis=1, inplace=True)
df22.drop('YEAR', axis=1, inplace=True)
test = groupby_borough = df22.groupby(['BOROUGH']).get_group(('BRONX',)).copy()
test.drop('BOROUGH', axis=1, inplace=True)

test['PREDICT'] = "-"
test['DELTA'] = "0"

# use 3 conditionals because not all targeted neighborhoods from the 2022 may appear in 2010-2021
for i, row in test.iterrows():
    if row['TYPE OF HOME'] == '01 ONE FAMILY HOMES' and row['NEIGHBORHOOD'] in dic_one:
        test.at[i, 'PREDICT'] = int(dic_one[row['NEIGHBORHOOD']])
        test.at[i, 'DELTA'] = int(row['AVERAGE SALE PRICE']) - int(dic_one[row['NEIGHBORHOOD']])
    elif row['TYPE OF HOME'] == '02 TWO FAMILY HOMES' and row['NEIGHBORHOOD'] in dic_two:
        test.at[i, 'PREDICT'] = int(dic_two[row['NEIGHBORHOOD']])
        test.at[i, 'DELTA'] = int(row['AVERAGE SALE PRICE']) - int(dic_two[row['NEIGHBORHOOD']])
    elif row['TYPE OF HOME'] == '03 THREE FAMILY HOMES' and row['NEIGHBORHOOD'] in dic_three:
        test.at[i, 'PREDICT'] = int(dic_three[row['NEIGHBORHOOD']])
        test.at[i, 'DELTA'] = int(row['AVERAGE SALE PRICE']) - int(dic_three[row['NEIGHBORHOOD']])
    
test
# Out:
#                  NEIGHBORHOOD           TYPE OF HOME  AVERAGE SALE PRICE  \
# 0                  BAYCHESTER    01 ONE FAMILY HOMES              533743
# 1                  BAYCHESTER    02 TWO FAMILY HOMES              702224
# 2                  BAYCHESTER  03 THREE FAMILY HOMES              781392
# 3        BEDFORD PARK/NORWOOD    01 ONE FAMILY HOMES              882762
# 4        BEDFORD PARK/NORWOOD    02 TWO FAMILY HOMES              717103
# 5        BEDFORD PARK/NORWOOD  03 THREE FAMILY HOMES              912231
# 6                     BELMONT    01 ONE FAMILY HOMES              725000
# 7                     BELMONT    02 TWO FAMILY HOMES              647772
# 8                     BELMONT  03 THREE FAMILY HOMES              745833
# 9                   BRONXDALE    01 ONE FAMILY HOMES              551676
# 10                  BRONXDALE    02 TWO FAMILY HOMES              729906
# 11                  BRONXDALE  03 THREE FAMILY HOMES              850206
# 12      CASTLE HILL/UNIONPORT    01 ONE FAMILY HOMES              622440
# 13      CASTLE HILL/UNIONPORT    02 TWO FAMILY HOMES              730497
# 14      CASTLE HILL/UNIONPORT  03 THREE FAMILY HOMES              922209
# 15                CITY ISLAND    01 ONE FAMILY HOMES              565419
# 16                CITY ISLAND    02 TWO FAMILY HOMES              664286
# 17                CITY ISLAND  03 THREE FAMILY HOMES              927333
# 18               COUNTRY CLUB    01 ONE FAMILY HOMES              665156
# 19               COUNTRY CLUB    02 TWO FAMILY HOMES              852886
# 20               COUNTRY CLUB  03 THREE FAMILY HOMES              980933
# 21                  SOUNDVIEW    02 TWO FAMILY HOMES              692505
# 22               CROTONA PARK    01 ONE FAMILY HOMES              607710
# 23               CROTONA PARK    02 TWO FAMILY HOMES              676143
# 24               CROTONA PARK  03 THREE FAMILY HOMES              796971
# 25               EAST TREMONT    01 ONE FAMILY HOMES              551308
# 26               EAST TREMONT    02 TWO FAMILY HOMES              753154
# 27               EAST TREMONT  03 THREE FAMILY HOMES              815000
# 28                  FIELDSTON    01 ONE FAMILY HOMES             2258443
# 29                  FIELDSTON    02 TWO FAMILY HOMES              820000
# 30                    FORDHAM    01 ONE FAMILY HOMES              950833
# 31                    FORDHAM    02 TWO FAMILY HOMES              783053
# 32                    FORDHAM  03 THREE FAMILY HOMES             1066851
# 33  HIGHBRIDGE/MORRIS HEIGHTS    01 ONE FAMILY HOMES              666286
# 34  HIGHBRIDGE/MORRIS HEIGHTS    02 TWO FAMILY HOMES              853454
# 35  HIGHBRIDGE/MORRIS HEIGHTS  03 THREE FAMILY HOMES              915250
# 36                HUNTS POINT    01 ONE FAMILY HOMES              555000
# 37                HUNTS POINT    02 TWO FAMILY HOMES              581000
# 38                HUNTS POINT  03 THREE FAMILY HOMES              430739
# 39   KINGSBRIDGE HTS/UNIV HTS    01 ONE FAMILY HOMES              793453
# 40   KINGSBRIDGE HTS/UNIV HTS    02 TWO FAMILY HOMES              694000
# 41   KINGSBRIDGE HTS/UNIV HTS  03 THREE FAMILY HOMES              781125
# 42    KINGSBRIDGE/JEROME PARK    01 ONE FAMILY HOMES              685600
# 43    KINGSBRIDGE/JEROME PARK    02 TWO FAMILY HOMES              958000
# 44    KINGSBRIDGE/JEROME PARK  03 THREE FAMILY HOMES             1038125
# 45          MELROSE/CONCOURSE    01 ONE FAMILY HOMES              560556
# 46          MELROSE/CONCOURSE    02 TWO FAMILY HOMES              923364
# 47          MELROSE/CONCOURSE  03 THREE FAMILY HOMES              741143
# 48       MORRIS PARK/VAN NEST    01 ONE FAMILY HOMES              665822
# 49       MORRIS PARK/VAN NEST    02 TWO FAMILY HOMES              766471
# 50       MORRIS PARK/VAN NEST  03 THREE FAMILY HOMES              875629
# 51        MORRISANIA/LONGWOOD    01 ONE FAMILY HOMES              505155
# 52        MORRISANIA/LONGWOOD    02 TWO FAMILY HOMES              711192
# 53        MORRISANIA/LONGWOOD  03 THREE FAMILY HOMES              806967
# 54     MOTT HAVEN/PORT MORRIS    01 ONE FAMILY HOMES              978700
# 55     MOTT HAVEN/PORT MORRIS    02 TWO FAMILY HOMES              878783
# 56     MOTT HAVEN/PORT MORRIS  03 THREE FAMILY HOMES              785500
# 57      MOUNT HOPE/MOUNT EDEN    01 ONE FAMILY HOMES             1126000
# 58      MOUNT HOPE/MOUNT EDEN    02 TWO FAMILY HOMES             1025769
# 59      MOUNT HOPE/MOUNT EDEN  03 THREE FAMILY HOMES             1070750
# 60                PARKCHESTER    01 ONE FAMILY HOMES              667500
# 61                PARKCHESTER    02 TWO FAMILY HOMES              714929
# 62                PARKCHESTER  03 THREE FAMILY HOMES              692851
# 63             PELHAM GARDENS    01 ONE FAMILY HOMES              692200
# 64             PELHAM GARDENS    02 TWO FAMILY HOMES              889545
# 65             PELHAM GARDENS  03 THREE FAMILY HOMES             1164750
# 66       PELHAM PARKWAY NORTH    01 ONE FAMILY HOMES              636963
# 67       PELHAM PARKWAY NORTH    02 TWO FAMILY HOMES              761124
# 68       PELHAM PARKWAY NORTH  03 THREE FAMILY HOMES             1058500
# 69       PELHAM PARKWAY SOUTH    01 ONE FAMILY HOMES              672794
# 70       PELHAM PARKWAY SOUTH    02 TWO FAMILY HOMES              828700
# 71       PELHAM PARKWAY SOUTH  03 THREE FAMILY HOMES              841667
# 72                  RIVERDALE    01 ONE FAMILY HOMES             1351782
# 73                  RIVERDALE    02 TWO FAMILY HOMES              990263
# 74                  RIVERDALE  03 THREE FAMILY HOMES             1129745
# 75   SCHUYLERVILLE/PELHAM BAY    01 ONE FAMILY HOMES              643243
# 76   SCHUYLERVILLE/PELHAM BAY    02 TWO FAMILY HOMES              824320
# 77   SCHUYLERVILLE/PELHAM BAY  03 THREE FAMILY HOMES             1005192
# 78                  SOUNDVIEW    01 ONE FAMILY HOMES              500603
# 79                  SOUNDVIEW  03 THREE FAMILY HOMES              846272
